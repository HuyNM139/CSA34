# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: C:\Users\Dell\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
fruit = {
    "A":"Apple",
    "B":"Banana",
    "C":"Carrot"
}
fruit_table = pd.Series(fruit)
fruit_table
# Out:
# A     Apple
# B    Banana
# C    Carrot
# dtype: str

# %%
weight = [37,48,42,39,41,38,40,40,43]
weight_table = pd.Series(weight,index=["Hoa","Nam","Hải","Linh","Nhân","Phương","Thu","Vũ","Bảo"])
weight_table
# pd.Series.mode(weight_table) #có mode,median,mean
# Out:
# Hoa       37
# Nam       48
# Hải       42
# Linh      39
# Nhân      41
# Phương    38
# Thu       40
# Vũ        40
# Bảo       43
# dtype: int64

# %%
animals = pd.DataFrame({
    "dong_vat":["Sao la", "Khi","Voi"],
    "tuoi":[25,25,70],
    "loai":["Có vú","linh trưởng","có vú"]
})
animals.to_csv("data.csv", index=False)
read = pd.read_csv("data.csv")
read
# Out:
#   dong_vat  tuoi         loai
# 0   Sao la    25        Có vú
# 1      Khi    25  linh trưởng
# 2      Voi    70        có vú
